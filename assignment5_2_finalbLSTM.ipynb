# %% [markdown]
# Now in 5_2 versions I am going to try the model with augmented datasets which I have created in the file dataset_gen.ipynb and stored doing pickling. Here I am going to load the pickled files only and test out the model.

# %%
import pandas as pd

# %%
import torch, torchtext
from torchtext import data

# %% [markdown]
# Here I am going to load the pickled files

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-831db1b1-ae4f-4ee9-9611-7a73444d6e90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-831db1b1-ae4f-4ee9-9611-7a73444d6e90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving trainset_new.pkl to trainset_new.pkl

# %%
import os, pickle

# %%
f1=open('trainset_new.pkl','rb')
tr_set=pickle.load(f1)
f1.close()

# %%
import random
import torch, torchtext
from torchtext import data

# %%
#Review
Review_text= torchtext.legacy.data.Field(sequential = True, tokenize = 'spacy', batch_first =True, include_lengths=True)
Label = torchtext.legacy.data.LabelField(tokenize ='spacy', is_target=True, batch_first =True, sequential =False)

# %%
fields = [('review',Review_text),('label',Label)]

# %%
train_set=torchtext.legacy.data.Dataset(tr_set,fields)

# %%
len(train_set)
# Out:
# 10225

# %%
uploaded=files.upload()
f1=open('testset.pkl','rb')
ts_set=pickle.load(f1)
f1.close()
# Out:
#      <input type="file" id="files-66896072-cff1-4b24-805e-b34432c5b0f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66896072-cff1-4b24-805e-b34432c5b0f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testset.pkl to testset.pkl

# %%
uploaded=files.upload()
f1=open('valset.pkl','rb')
vl_set=pickle.load(f1)
f1.close()
# Out:
#      <input type="file" id="files-1ec1e7ea-34cd-45c5-a68f-754838556e49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ec1e7ea-34cd-45c5-a68f-754838556e49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving valset.pkl to valset.pkl

# %%
#train_example = [torchtext.legacy.data.Example.fromlist([df.text[i],df.label[i]], fields) for i in range(df.shape[0])]

# %%
#train_set=torchtext.legacy.data.Dataset(train_example,fields)

# %%
test_set=torchtext.legacy.data.Dataset(ts_set,fields)
val_set=torchtext.legacy.data.Dataset(vl_set,fields)

# %%
#test_example = [torchtext.legacy.data.Example.fromlist([test_set.text[i],test_set.label[i]], fields) for i in range(test_set.shape[0])] 
#val_example = [torchtext.legacy.data.Example.fromlist([val_set.text[i],val_set.label[i]], fields) for i in range(val_set.shape[0])]

# %%
len(train_set),len(test_set),len(val_set)
# Out:
# (10225, 2210, 1101)

# %%
Review_text.build_vocab(train_set)
Label.build_vocab(train_set)

# %%
print('Size of input vocab : ', len(Review_text.vocab))
print('Size of label vocab : ', len(Label.vocab))
print('Top 10 words appreared repeatedly :', list(Review_text.vocab.freqs.most_common(10)))
print('Labels : ', Label.vocab.stoi)
# Out:
# Size of input vocab :  18489
# Size of label vocab :  5
# Top 10 words appreared repeatedly : [('.', 9418), (',', 8453), ('the', 7353), ('and', 5438), ('of', 5280), ('a', 5189), ('to', 3579), ('is', 3188), ('-', 3102), ("'s", 2772)]
# Labels :  defaultdict(None, {'4': 0, '2': 1, '5': 2, '3': 3, '1': 4})

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
train_iterator = torchtext.legacy.data.BucketIterator(train_set, batch_size = 64, shuffle=True, device=device)
#                                                           sort_key = lambda x: len(x.review),
#                                                           sort_within_batch=True, device = device)

# %%
valid_iterator = torchtext.legacy.data.BucketIterator(val_set, batch_size = 64, shuffle=True, device=device)
#                                                            sort_key = lambda x: len(x.review),
#                                                           sort_within_batch=True, device = device)

# %%
test_iterator = torchtext.legacy.data.BucketIterator(test_set, batch_size = 64, shuffle=True, device=device)
#                                                            sort_key = lambda x: len(x.review),
#                                                            sort_within_batch=True, device = device)

# %%
import os, pickle
with open('tokenizer.pkl', 'wb') as tokens: 
    #pickle.dump(Tweet.vocab.stoi, tokens)
    pickle.dump(Review_text.vocab.stoi,tokens)

# %%
import torch.nn as nn
import torch.nn.functional as F

class classifier(nn.Module):
    
    # Define all the layers used in model
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, n_layers, dropout):
        
        super(classifier,self).__init__()   
        self.embedding_dim=embedding_dim
        self.hidden_dim=hidden_dim
        self.output_dim=output_dim
        self.n_layers=n_layers       
        self.directions=2
        
        # Embedding layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        
        # LSTM layer
        self.encoder = nn.LSTM(embedding_dim, 
                           hidden_dim, 
                           n_layers, 
                           #dropout=dropout,
                           batch_first=True,bidirectional=True)
        # try using nn.GRU or nn.RNN here and compare their performances
        # try bidirectional and compare their performances
        
        # Dense layer
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, text, text_lengths):
        
        # text = [batch size, sent_length]
        embedded = self.embedding(text)
        # embedded = [batch size, sent_len, emb dim]
      
        # packed sequence
        batch_size=text.size(0)
        next=self.n_layers*2
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths.cpu(), batch_first=True, enforce_sorted=False)
        #hidden=torch.zeros(next,self.hidden_dim).to(device)
        packed_output_f, (hidden,cell) = self.encoder(packed_embedded)
        #hidden = [batch size, num layers * num directions,hid dim]
        #cell = [batch size, num layers * num directions,hid dim]
    
        # Hidden = [batch size, hid dim * num directions]
        #dense_outputs = self.fc(packed_output_f[:,-1,:]) 
        dense_outputs = self.fc(hidden)     
        
        # Final activation function softmax
        output = F.softmax(dense_outputs[0], dim=1)
            
        return output

# %%
# Define hyperparameters
size_of_vocab=len(Review_text.vocab)
embedding_dim = 500
num_hidden_nodes = 100
num_output_nodes = 5
num_layers = 2
dropout = 0.2

# Instantiate the model
model = classifier(size_of_vocab, embedding_dim, num_hidden_nodes, num_output_nodes, num_layers, dropout = dropout)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a3a274f8a85d> in <module>()
#       1 # Define hyperparameters
# ----> 2 size_of_vocab=len(Review_text.vocab)
#       3 embedding_dim = 500
#       4 num_hidden_nodes = 100
#       5 num_output_nodes = 5
#
# NameError: name 'Review_text' is not defined

# %%
print(model)

#No. of trianable parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# classifier(
#   (embedding): Embedding(18489, 500)
#   (encoder): LSTM(500, 100, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=100, out_features=5, bias=True)
# )
# The model has 9,968,205 trainable parameters

# %%
device
# Out:
# device(type='cuda')

# %%
import torch.optim as optim

# define optimizer and loss
optimizer = optim.Adam(model.parameters(), lr=2e-4)
criterion = nn.CrossEntropyLoss()

# define metric
def binary_accuracy(preds, y):
    #round predictions to the closest integer
    _, predictions = torch.max(preds, 1)
    
    correct = (predictions == y).float() 
    acc = correct.sum() / len(correct)
    return acc

def cat_accuracy(preds,y):
    top_pred=preds.argmax(1,keepdim=True)
    correct=top_pred.eq(y.view_as(top_pred)).sum()
    acc=correct.float()/y.shape[0]
    return acc
    
# push to cuda if available
model = model.to(device)
criterion = criterion.to(device)

# %%
b=next(iter(train_iterator))
review,review_length=b.review

# %%
predictions=model(review,review_length)
predictions.shape

optimizer.zero_grad()
loss = criterion(predictions, b.label)   
L2_lambda=0.001
L2_norm=sum(p.pow(2.0).sum() for p in model.parameters())    
loss=loss+L2_lambda*L2_norm     
acc = cat_accuracy(predictions, b.label)   
loss.backward()       
optimizer.step()

# %%
loss.item()
# Out:
# 9247.861328125

# %%
def train(model, iterator, optimizer, criterion):
    
    # initialize every epoch 
    epoch_loss = 0
    epoch_acc = 0
    
    # set the model in training phase
    model.train()  
    
    for batch in iterator:
        
        # resets the gradients after every batch
        optimizer.zero_grad()   
        
        # retrieve text and no. of words
        #tweet, tweet_lengths = batch.tweet  
        review,review_length = batch.review
        
        # convert to 1D tensor
        #predictions = model(tweet, tweet_lengths).squeeze()  
        predictions=model(review,review_length)
        
        # compute the loss
        loss = criterion(predictions, batch.label)    
        #adding regularization
        L2_lambda=0.001
        L2_norm=sum(p.pow(2.0).sum() for p in model.parameters())    
        loss=loss+L2_lambda*L2_norm
        
        # compute the categorical accuracy
        acc = cat_accuracy(predictions, batch.label)   
        
        # backpropage the loss and compute the gradients
        loss.backward()       
        
        # update the weights
        optimizer.step()      
        
        # loss and accuracy
        epoch_loss += loss.item()  
        epoch_acc += acc.item()    
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    # initialize every epoch
    epoch_loss = 0
    epoch_acc = 0

    # deactivating dropout layers
    model.eval()
    
    # deactivates autograd
    with torch.no_grad():
    
        for batch in iterator:
        
            # retrieve text and no. of words
            #tweet, tweet_lengths = batch.tweet
            review,review_length = batch.review
            
            # convert to 1d tensor
            predictions = model(review, review_length).squeeze()
            
            # compute loss and accuracy
            loss = criterion(predictions, batch.label)
            acc = cat_accuracy(predictions, batch.label)
            
            # keep track of loss and accuracy
            epoch_loss += loss.item()
            epoch_acc += acc.item()
        
    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %%
device
# Out:
# device(type='cuda')

# %%
import matplotlib.pyplot as plt
from IPython import display
plt.style.use('seaborn-white')
import numpy as np

# %%
N_EPOCHS = 50
best_valid_loss = float('inf')
global plot_iter, plot_loss_train, plot_loss_val
plot_iter = np.zeros((0))
plot_loss_train = np.zeros((0))
plot_loss_val = np.zeros((0))
plot_loss_test=np.zeros((0))
for epoch in range(N_EPOCHS):
     
    # train the model
    train_loss, train_acc = train(model, train_iterator, optimizer, criterion)
    
    # evaluate the model
    valid_loss, valid_acc = evaluate(model, valid_iterator, criterion)
    # evaluate the model on test data
    test_loss, test_acc = evaluate(model, test_iterator, criterion)
    # save the best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        best_valid_acc=valid_acc
        torch.save(model.state_dict(), 'saved_weights.pt')
    
    print(f'\t epoch : {epoch} |\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. Acc: {valid_acc*100:.2f}% \n')
    plot_iter = np.append(plot_iter, [epoch])
    plot_loss_train = np.append(plot_loss_train, [train_loss])
    plot_loss_val = np.append(plot_loss_val, [valid_loss])
print(f'\Best Valid Accuracy :{best_valid_acc*100:.2f}\n')
# Out:
# 	 epoch : 0 |	Train Loss: 515.549 | Train Acc: 67.55%
# 	 Val. Loss: 1.543 |  Val. Acc: 34.09%
#
# 	 epoch : 1 |	Train Loss: 480.739 | Train Acc: 68.14%
# 	 Val. Loss: 1.566 |  Val. Acc: 31.94%
#
# 	 epoch : 2 |	Train Loss: 448.016 | Train Acc: 68.60%
# 	 Val. Loss: 1.548 |  Val. Acc: 33.21%
#
# 	 epoch : 3 |	Train Loss: 417.277 | Train Acc: 68.06%
# 	 Val. Loss: 1.553 |  Val. Acc: 33.31%
#
# 	 epoch : 4 |	Train Loss: 388.417 | Train Acc: 67.38%
# 	 Val. Loss: 1.540 |  Val. Acc: 34.51%
#
# 	 epoch : 5 |	Train Loss: 361.327 | Train Acc: 68.70%
# 	 Val. Loss: 1.542 |  Val. Acc: 34.52%
#
# 	 epoch : 6 |	Train Loss: 335.933 | Train Acc: 68.40%
# 	 Val. Loss: 1.533 |  Val. Acc: 36.34%
#
# 	 epoch : 7 |	Train Loss: 312.137 | Train Acc: 68.47%
# 	 Val. Loss: 1.552 |  Val. Acc: 32.02%
#
# 	 epoch : 8 |	Train Loss: 289.854 | Train Acc: 68.84%
# 	 Val. Loss: 1.536 |  Val. Acc: 34.87%
#
# 	 epoch : 9 |	Train Loss: 269.009 | Train Acc: 68.53%
# 	 Val. Loss: 1.544 |  Val. Acc: 34.43%
#
# 	 epoch : 10 |	Train Loss: 249.503 | Train Acc: 69.70%
# 	 Val. Loss: 1.541 |  Val. Acc: 34.87%
#
# 	 epoch : 11 |	Train Loss: 231.274 | Train Acc: 70.22%
# 	 Val. Loss: 1.550 |  Val. Acc: 33.14%
#
# 	 epoch : 12 |	Train Loss: 214.262 | Train Acc: 69.70%
# 	 Val. Loss: 1.553 |  Val. Acc: 32.62%
#
# 	 epoch : 13 |	Train Loss: 198.378 | Train Acc: 70.51%
# 	 Val. Loss: 1.554 |  Val. Acc: 32.81%
#
# 	 epoch : 14 |	Train Loss: 183.569 | Train Acc: 70.37%
# 	 Val. Loss: 1.528 |  Val. Acc: 36.42%
#
# 	 epoch : 15 |	Train Loss: 169.786 | Train Acc: 68.67%
# 	 Val. Loss: 1.536 |  Val. Acc: 35.20%
#
# 	 epoch : 16 |	Train Loss: 156.917 | Train Acc: 70.88%
# 	 Val. Loss: 1.531 |  Val. Acc: 34.86%
#
# 	 epoch : 17 |	Train Loss: 144.953 | Train Acc: 71.19%
# 	 Val. Loss: 1.529 |  Val. Acc: 35.80%
#
# 	 epoch : 18 |	Train Loss: 133.830 | Train Acc: 71.09%
# 	 Val. Loss: 1.538 |  Val. Acc: 34.69%
#
# 	 epoch : 19 |	Train Loss: 123.492 | Train Acc: 71.39%
# 	 Val. Loss: 1.539 |  Val. Acc: 34.78%
#
# 	 epoch : 20 |	Train Loss: 113.893 | Train Acc: 71.21%
# 	 Val. Loss: 1.524 |  Val. Acc: 36.67%
#
# 	 epoch : 21 |	Train Loss: 104.995 | Train Acc: 70.75%
# 	 Val. Loss: 1.535 |  Val. Acc: 34.53%
#
# 	 epoch : 22 |	Train Loss: 96.724 | Train Acc: 71.70%
# 	 Val. Loss: 1.536 |  Val. Acc: 34.88%
#
# 	 epoch : 23 |	Train Loss: 89.064 | Train Acc: 72.38%
# 	 Val. Loss: 1.535 |  Val. Acc: 35.47%
#
# 	 epoch : 24 |	Train Loss: 81.967 | Train Acc: 72.59%
# 	 Val. Loss: 1.526 |  Val. Acc: 36.60%
#
# 	 epoch : 25 |	Train Loss: 75.412 | Train Acc: 72.37%
# 	 Val. Loss: 1.520 |  Val. Acc: 37.12%
#
# 	 epoch : 26 |	Train Loss: 69.332 | Train Acc: 73.54%
# 	 Val. Loss: 1.539 |  Val. Acc: 35.66%
#
# 	 epoch : 27 |	Train Loss: 63.730 | Train Acc: 72.69%
# 	 Val. Loss: 1.529 |  Val. Acc: 36.35%
#
# 	 epoch : 28 |	Train Loss: 58.553 | Train Acc: 72.68%
# 	 Val. Loss: 1.519 |  Val. Acc: 37.29%
#
# 	 epoch : 29 |	Train Loss: 53.780 | Train Acc: 72.11%
# 	 Val. Loss: 1.520 |  Val. Acc: 37.47%
#
# 	 epoch : 30 |	Train Loss: 49.356 | Train Acc: 74.29%
# 	 Val. Loss: 1.526 |  Val. Acc: 35.99%
#
# 	 epoch : 31 |	Train Loss: 45.290 | Train Acc: 74.46%
# 	 Val. Loss: 1.532 |  Val. Acc: 35.40%
#
# 	 epoch : 32 |	Train Loss: 41.552 | Train Acc: 74.29%
# 	 Val. Loss: 1.523 |  Val. Acc: 37.03%
#
# 	 epoch : 33 |	Train Loss: 38.107 | Train Acc: 74.63%
# 	 Val. Loss: 1.541 |  Val. Acc: 34.17%
#
# 	 epoch : 34 |	Train Loss: 34.949 | Train Acc: 73.97%
# 	 Val. Loss: 1.521 |  Val. Acc: 36.85%
#
# 	 epoch : 35 |	Train Loss: 32.022 | Train Acc: 75.66%
# 	 Val. Loss: 1.532 |  Val. Acc: 35.30%
#
# 	 epoch : 36 |	Train Loss: 29.369 | Train Acc: 72.96%
# 	 Val. Loss: 1.520 |  Val. Acc: 37.39%
#
# 	 epoch : 37 |	Train Loss: 26.911 | Train Acc: 74.33%
# 	 Val. Loss: 1.539 |  Val. Acc: 34.17%
#
# 	 epoch : 38 |	Train Loss: 24.651 | Train Acc: 75.55%
# 	 Val. Loss: 1.547 |  Val. Acc: 34.78%
#
# 	 epoch : 39 |	Train Loss: 22.615 | Train Acc: 72.99%
# 	 Val. Loss: 1.520 |  Val. Acc: 37.21%
#
# 	 epoch : 40 |	Train Loss: 20.722 | Train Acc: 74.33%
# 	 Val. Loss: 1.526 |  Val. Acc: 36.25%
#
# 	 epoch : 41 |	Train Loss: 18.977 | Train Acc: 76.25%
# 	 Val. Loss: 1.549 |  Val. Acc: 33.39%
#
# 	 epoch : 42 |	Train Loss: 17.395 | Train Acc: 76.53%
# 	 Val. Loss: 1.534 |  Val. Acc: 35.40%
#
# 	 epoch : 43 |	Train Loss: 15.944 | Train Acc: 77.59%
# 	 Val. Loss: 1.540 |  Val. Acc: 34.69%
#
# 	 epoch : 44 |	Train Loss: 14.628 | Train Acc: 77.09%
# 	 Val. Loss: 1.537 |  Val. Acc: 34.96%
#
# 	 epoch : 45 |	Train Loss: 13.423 | Train Acc: 76.92%
# 	 Val. Loss: 1.542 |  Val. Acc: 34.01%
#
# 	 epoch : 46 |	Train Loss: 12.321 | Train Acc: 77.64%
# 	 Val. Loss: 1.538 |  Val. Acc: 35.12%
#
# 	 epoch : 47 |	Train Loss: 11.319 | Train Acc: 77.36%
# 	 Val. Loss: 1.557 |  Val. Acc: 32.26%
#
# 	 epoch : 48 |	Train Loss: 10.404 | Train Acc: 77.85%
# 	 Val. Loss: 1.545 |  Val. Acc: 34.95%
#
# 	 epoch : 49 |	Train Loss: 9.577 | Train Acc: 77.56%
# 	 Val. Loss: 1.548 |  Val. Acc: 34.18%
#
# \Best Valid Accuracy :37.29

# %%
plt.plot(plot_iter, plot_loss_train, plot_loss_val)
display.clear_output(wait=True)
plt.show()

# %%
test_iterator = torchtext.legacy.data.BucketIterator(test_set, batch_size = 10, shuffle=True)

# %%
#load weights and tokenizer

path='./saved_weights.pt'
model.load_state_dict(torch.load(path));
model.eval();
tokenizer_file = open('./tokenizer.pkl', 'rb')
tokenizer = pickle.load(tokenizer_file)

#inference 

import spacy
nlp = spacy.load('en')

def classify_review(t):
    
    categories = {0: "Positive",1:"Negative", 2:"Neutral", 3:"Very Positive", 4:"Very Negative"}
    
  
    tokenized = [tok.text for tok in nlp.tokenizer(t)] 
    # convert to integer sequence using predefined tokenizer dictionary
    indexed = [tokenizer[t] for t in tokenized]        
    # compute no. of words        
    length = [len(indexed)]
    # convert to tensor                                    
    tensor = torch.LongTensor(indexed).to(device)   
    # reshape in form of batch, no. of words           
    tensor = tensor.unsqueeze(1).T  
    # convert to tensor                          
    length_tensor = torch.LongTensor(length)
    # Get the model prediction                  
    prediction = model(tensor, length_tensor)
    #print(prediction)
    #print(prediction.max())
    #print(categories)
    _, pred = torch.max(prediction, 1) 
    #print(pred.item()) 
    return categories[pred.item()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ac02873fbe64> in <module>()
#       2
#       3 path='./saved_weights.pt'
# ----> 4 model.load_state_dict(torch.load(path));
#       5 model.eval();
#       6 tokenizer_file = open('./tokenizer.pkl', 'rb')
#
# NameError: name 'model' is not defined

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bb17e8d8-9bf8-475b-98b4-523796ad5d96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb17e8d8-9bf8-475b-98b4-523796ad5d96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_sent.pkl to test_sent.pkl

# %%
f1=open('test_sent.pkl','rb')
tst=pickle.load(f1)
f1.close()

# %%
import random
random.seed(43)

# %%
r_n=random.choice(tst)

# %%
print(r_n)
# Out:
# Its mysteries are transparently obvious , and it 's too slowly paced to be a thriller .

# %%
for i in range(10):
  r_n=random.choice(tst)
  #print(r_n)
  p=classify_review(r_n)
  print(f'{r_n} | sentiment : {p}')
# Out:
# Well-shot but badly written tale set in a future ravaged by dragons . | sentiment : Very Positive
# Elicits more groans from the audience than Jar Jar Binks , Scrappy Doo and Scooby Dumb , all wrapped up into one . | sentiment : Negative
# The year 's happiest surprise , a movie that deals with a real subject in an always surprising way . | sentiment : Positive
# ... ambition is in short supply in the cinema , and Egoyan tackles his themes and explores his characters ' crises with seriousness and compassion . | sentiment : Positive
# What really surprises about Wisegirls is its low-key quality and genuine tenderness . | sentiment : Positive
# A splendid entertainment , young in spirit but accomplished in all aspects with the fullness of spirit and sense of ease that comes only with experience . | sentiment : Positive
# Almost every scene in this film is a gem that could stand alone , a perfectly realized observation of mood , behavior and intent . | sentiment : Positive
# Too sincere to exploit its subjects and too honest to manipulate its audience . | sentiment : Negative
# At heart the movie is a deftly wrought suspense yarn whose richer shadings work as coloring rather than substance . | sentiment : Positive
# Although based on a real-life person , John , in the movie , is a rather dull person to be stuck with for two hours . | sentiment : Positive
